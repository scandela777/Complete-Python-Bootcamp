# %% [markdown]
# ##### Importing Modules in Python: Modules and Packages
# In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
# con esto se importa el paquete completo
import math
math.sqrt(16)
# Out:
# 4.0

# %%
# De esta manera, se importa únicamente las funciones necesarias 
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(round(sqrt(pi),2))
# Out:
# 4.0
# 5.0
# 1.77

# %%
#En este caso, np es un alias del paquete.
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
#Para usar paquetes creados por uno mismo, se requiere crear una carpeta y empezar por el archivo __init__.py. Es usado para inicializar los nombres de los paquetes 
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5

# %% [markdown]
# #### Conclusion
# Importing modules and packages in Python allows you to organize your code, reuse functionalities, and keep your projects clean and manageable. By understanding how to import modules, specific functions, and use relative imports within packages, you can structure your Python applications more effectively.
