# %%
with open('example.txt') as file:
    content=file.read()
    print(content)
# Out:
# Hello world
# This is a new line

# %%
with open('example.txt') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello world
# This is a new line

# %%
with open('example.txt','w') as file:
    for i in range (10):
        file.write('Hello World \n')

# %%
with open('example.txt') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
